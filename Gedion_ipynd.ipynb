# %% [markdown]
# <a href="https://colab.research.google.com/github/6f2qvh692h-debug/Gedion/blob/main/Gedion_ipynd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_digits
digits = load_digits()

# %%
digits = load_digits()

# %%
print(digits)
# Out:
# {'data': array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
# ...

# %%
digits.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'images', 'DESCR'])

# %%
print(digits["target"][0])
# Out:
# 0

# %%
digits["data"].shape
# Out:
# (1797, 64)

# %%
def plot_image(pixelmap, ax = None):
  if not ax:
    ax = plt.gca()

  ax.set_yticks([]);ax.set_xticks([])
  ax.imshow(np.reshape(pixelmap, (8,8)))

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

# Load the digits dataset
digits = load_digits()

# Plot the first image in the dataset with a colormap
plt.imshow(digits["data"][3].reshape(8, 8), cmap="Reds")
plt.title("Witch nummber?")
plt.colorbar()
plt.show()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(digits["data"], digits["target"], test_size= 0.3)

# %%
X_test.shape
# Out:
# (540, 64)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()

# %%
clf.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# Dataset laden
digits = load_digits()

def zeige_bild(index):
    plt.imshow(digits["data"][index].reshape(8, 8), cmap="Reds")
    plt.title(f"witch nummber) (Bild {index})")
    plt.colorbar()
    plt.show()

# Slider erstellen
slider = widgets.IntSlider(value=0, min=0, max=len(digits.data)-1, description='Number:')
widgets.interact(zeige_bild, index=slider)
# Out:
# interactive(children=(IntSlider(value=0, description='Number:', max=1796), Output()), _dom_classes=('widget-in…
# <function __main__.zeige_bild(index)>
